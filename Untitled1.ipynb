# %% [markdown]
# <a href="https://colab.research.google.com/github/GunaSree975/AutiCare/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch accelerate -q

# %%
from transformers import pipeline

# Load a small open-source model
assistant = pipeline('text2text-generation', model='google/flan-t5-base')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
chat_history = []

def ask_ai(user_input):
    global chat_history
    # Add user input to history
    chat_history.append(f'User: {user_input}')

    # Use last 5 turns as context
    context = '\n'.join(chat_history[-5:])

    # Generate response
    response = assistant(
        context,
        max_length=60,
        num_beams=5,
        no_repeat_ngram_size=2,
        do_sample=True,
        top_k=50,
        top_p=0.95
    )[0]['generated_text']
    # Save response
    chat_history.append(f'Assistant: {response}')
    return response

# %%
while True:
    user_input = input('You: ')
    if user_input.lower() in ['exit', 'quit', 'bye']:
        print('👋 Assistant: Goodbye!')
        break
    reply = ask_ai(user_input)
    print('🤖 Assistant:', reply)
# Out:
# You: hello
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🤖 Assistant: hello. how can i help you?
# You: who are you?
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🤖 Assistant: Assistant: Hello. How can I help you?
# You: bye
# 👋 Assistant: Goodbye!
